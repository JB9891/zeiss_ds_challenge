# %%
import pandas as pd
import numpy as np
import pandas_profiling
import sys
import os

from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2

from src.data_processing import *
from src.utils import *

from sklearn.feature_selection import SelectKBest, chi2, f_classif
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Read the data
path = '../data/CustomerData_LeadGenerator.csv'
data_raw = load_raw(path)

# Check dtypes
data_raw.dtypes
# Out:
# fakeID                                             object
# b_specialisation_i                                  int64
# b_specialisation_h                                  int64
# b_specialisation_g                                  int64
# b_specialisation_f                                  int64
# b_specialisation_e                                  int64
# b_specialisation_d                                  int64
# b_specialisation_c                                  int64
# b_specialisation_b                                  int64
# b_specialisation_a                                  int64
# b_specialisation_j                                  int64
# q_OpeningDays                                       int64
# q_OpeningHours                                     object
# q_2017 Average Household Size                     float64
# q_2017 Total Households                             int64
# q_2017 HHs: 5th Quintile (68.759 and above)         int64
# q_5th Quint by Total HH                           float64
# q_2017 Purchasing Power: Per Capita               float64
# q_2017 Total Population                             int64
# q_2017 Pop 15+/Edu: University, Fachhochschule      int64
# q_Uni by Total Pop                                float64
# q_2017 Personal Care: Per Capita                  float64
# q_2017 Medical Products: Per Capita               float64
# q_2017 Personal Effects: Per Capita               float64
# b_in_kontakt_gewesen                                int64
# b_gekauft_gesamt                                    int64
# dtype: object

# %%
# Check why Opening hours is type object
mask = pd.to_numeric(data_raw['q_OpeningHours'], errors='coerce').isna()
print(f"number of non numeric values: {sum(mask)}")
# Out:
# number of non numeric values: 1

# %%
# Account for non numeric value in data_raw['q_OpeningHours']
data_clean = clean(data_raw)

# %%
# Use pandas profiling to interactively explore raw data in html report
profiling_reports(data_raw, "zeiss_raw_data")
# Out:
# Summarize dataset:   0%|          | 0/39 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Notes of first report
# - Data fake id column is unique so no duplicated potential customer
# - Data set might be a list of offices of doctors, due to specialization columns
# - Only a small fraction of 95 have been contacted, and 57 bought something if we assume that value 1 stand for a true value in b_in_kontakt_gewesen and b_gekauft_gesamt
# - A lot of zeros in opening days (26,6%) --> If the assumption that each row retapresents a doctors office is true this might either be wrong data or it might mean that the office is not existing anymore
# - Opening Hours had a issue with a non numeric value
# - High correlation of numeric data

# %%
# Split data in train and secret test data
train, secret =  split_train_secret(data_clean)

# %%
# Create pandas profiling reports for raw data and secret data
reports = {'zeiss_train': train, 'zeiss_secret': secret}
for key, value in reports.items():
    profiling_reports(value, key)
# Out:
# Summarize dataset:   0%|          | 0/39 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/39 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Notes of train and secret report
# - Distribution of specialisation g,f and j heavily differ from train and test
# - In train still 27.4% of data with 0 Opening Days & 27.4% in opening hours --> Assumption --> Missing data --> Therefore impute
# - Clean opening hours in secret test set
# - Maybe Check for outlier and irrealistic values --> No completely unrealistic values for all other numerical variables
# - Other distributions of features look quite similar (eyeball estimate)

# %% [markdown]
# # Deep Dive into correlation of numeric features

# %%
# List with numeric features ordered by assumed similarity
num_cols = [
    'q_OpeningDays',
    'q_OpeningHours',
    'q_2017 Average Household Size',
    'q_2017 Total Households',
    'q_2017 HHs: 5th Quintile (68.759 and above)',
    'q_2017 Total Population',
    'q_2017 Pop 15+/Edu: University, Fachhochschule',
    'q_Uni by Total Pop',
    'q_5th Quint by Total HH',
    'q_2017 Purchasing Power: Per Capita',
    'q_2017 Personal Care: Per Capita',
    'q_2017 Personal Effects: Per Capita',
    'q_2017 Medical Products: Per Capita',
]

# Get correlation matrix
corr = data_clean[num_cols].corr()

# Plot correlation matrix
corr.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_4908f_row0_col0, #T_4908f_row1_col1, #T_4908f_row2_col2, #T_4908f_row3_col3, #T_4908f_row3_col4, #T_4908f_row3_col5, #T_4908f_row3_col6, #T_4908f_row4_col3, #T_4908f_row4_col4, #T_4908f_row4_col5, #T_4908f_row4_col6, #T_4908f_row5_col3, #T_4908f_row5_col4, #T_4908f_row5_col5, #T_4908f_row5_col6, #T_4908f_row6_col3, #T_4908f_row6_col4, #T_4908f_row6_col5, #T_4908f_row6_col6, #T_4908f_row7_col7, #T_4908f_row8_col8, #T_4908f_row9_col9, #T_4908f_row10_col10, #T_4908f_row11_col11, #T_4908f_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4908f_row0_col1, #T_4908f_row1_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_4908f_row0_col2, #T_4908f_row11_col3 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_4908f_row0_col3, #T_4908f_row0_col5 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_4908f_row0_col4, #T_4908f_row4_col12 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_4908f_row0_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_4908f_row0_col7, #T_4908f_row1_col3, #T_4908f_row1_col5, #T_4908f_row11_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_4908f_row0_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_4908f_row0_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_4908f_row0_col10 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_4908f_row0_col11, #T_4908f_row12_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4908f_row0_col12 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_4908f_row1_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_4908f_row1_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_4908f_row1_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_4908f_row1_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_4908f_row1_col8, #T_4908f_row1_col11, #T_4908f_row3_col1, #T_4908f_row5_col1, #T_4908f_row9_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_4908f_row1_col9, #T_4908f_row4_col11 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_4908f_row1_col10 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_4908f_row1_col12 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_4908f_row2_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_4908f_row2_col1, #T_4908f_row12_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_4908f_row2_col3, #T_4908f_row2_col4, #T_4908f_row2_col5, #T_4908f_row2_col6, #T_4908f_row2_col7, #T_4908f_row2_col9, #T_4908f_row2_col10, #T_4908f_row2_col11, #T_4908f_row2_col12, #T_4908f_row6_col8, #T_4908f_row7_col2, #T_4908f_row8_col1, #T_4908f_row10_col2, #T_4908f_row11_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4908f_row2_col8 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_4908f_row3_col0, #T_4908f_row5_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4908f_row3_col2, #T_4908f_row4_col2, #T_4908f_row5_col2, #T_4908f_row6_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_4908f_row3_col7, #T_4908f_row4_col7 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_4908f_row3_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4908f_row3_col9, #T_4908f_row5_col9 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_4908f_row3_col10, #T_4908f_row5_col10 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_4908f_row3_col11, #T_4908f_row11_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_4908f_row3_col12, #T_4908f_row5_col12 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_4908f_row4_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_4908f_row4_col1, #T_4908f_row7_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_4908f_row4_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_4908f_row4_col9 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_4908f_row4_col10 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_4908f_row5_col7 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_4908f_row5_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4908f_row5_col11 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_4908f_row6_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_4908f_row6_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_4908f_row6_col7 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_4908f_row6_col9 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_4908f_row6_col10, #T_4908f_row10_col4 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_4908f_row6_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_4908f_row6_col12 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_4908f_row7_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_4908f_row7_col3, #T_4908f_row7_col4, #T_4908f_row7_col5 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_4908f_row7_col6 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_4908f_row7_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4908f_row7_col9, #T_4908f_row10_col3, #T_4908f_row10_col5 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_4908f_row7_col10, #T_4908f_row10_col7 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_4908f_row7_col11, #T_4908f_row8_col10, #T_4908f_row11_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_4908f_row7_col12 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_4908f_row8_col0, #T_4908f_row9_col1, #T_4908f_row10_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_4908f_row8_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_4908f_row8_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_4908f_row8_col4, #T_4908f_row8_col12 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_4908f_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_4908f_row8_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_4908f_row8_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_4908f_row8_col9, #T_4908f_row11_col7 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_4908f_row8_col11 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_4908f_row9_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_4908f_row9_col3, #T_4908f_row9_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_4908f_row9_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_4908f_row9_col6 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_4908f_row9_col7 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_4908f_row9_col8 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_4908f_row9_col10 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_4908f_row9_col11 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_4908f_row9_col12 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_4908f_row10_col1, #T_4908f_row12_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4908f_row10_col6 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_4908f_row10_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_4908f_row10_col9 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_4908f_row10_col11 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_4908f_row10_col12 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_4908f_row11_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4908f_row11_col5 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_4908f_row11_col8 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_4908f_row11_col9 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_4908f_row11_col10 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_4908f_row11_col12 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_4908f_row12_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4908f_row12_col3, #T_4908f_row12_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_4908f_row12_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_4908f_row12_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_4908f_row12_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_4908f_row12_col9 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_4908f_row

# %% [markdown]
# # Check unrealistic values for opening days and opening hours

# %%
# Ceck if all values with opening hours = 0 have opening days = 0
cond_1 = data_clean['q_OpeningDays'] == 0
cond_2 = data_clean['q_OpeningHours'] == 0
print(f"# of records in whole data set with unlogic combination of q_OpeningDays and q_OpeningHours: "
      f"{data_clean[(cond_1 & ~cond_2) | (~cond_1 & cond_2)].shape[0]}")

# Check if opening hours per day has unrealistic values 
print(f"Max value of OpeningHours/OpeningDay: "
      f"{max(data_clean['q_OpeningHours']/data_clean['q_OpeningDays'])}")

# Check if there are any records in the training data having 0 opening hours but a true value in b_gekauft_gesamt
print(f"# of records with o q_OpeningHours but flagges as customer: "
      f"{train.loc[(cond_1 & cond_2), 'b_gekauft_gesamt'].sum()}")
# Out:
# # of records in whole data set with unlogic combination of q_OpeningDays and q_OpeningHours: 0
# Max value of OpeningHours/OpeningDay: 12.0
# # of records with o q_OpeningHours but flagges as customer:  17

# %% [markdown]
# # Impute 0 values of opening hour with mean()
# - In real sceanrio a feedback loop with the owner of the data would be preferred

# %%
# Impute data
data_imputed = impute(data_clean)

# Overwrite train and test split
train, secret =  split_train_secret(data_imputed)

# %% [markdown]
# # Manual feature selection of numeric features

# %%
# Manually select numerical features to dela with high multicollinearity
keep_num_features =  [
    'q_OpeningHours',
    'q_2017 Total Households',
    'q_2017 Purchasing Power: Per Capita',
    'q_2017 Medical Products: Per Capita',
    'q_5th Quint by Total HH'
]

# Get correlation matrix
corr_keep = data_imputed[keep_num_features].corr()

# Plot correlation matrix
corr_keep.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_bb37b_row0_col0, #T_bb37b_row1_col1, #T_bb37b_row2_col2, #T_bb37b_row3_col3, #T_bb37b_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bb37b_row0_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_bb37b_row0_col2, #T_bb37b_row1_col4, #T_bb37b_row4_col0, #T_bb37b_row4_col1, #T_bb37b_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bb37b_row0_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_bb37b_row0_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_bb37b_row1_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_bb37b_row1_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_bb37b_row1_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_bb37b_row2_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_bb37b_row2_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_bb37b_row2_col3 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_bb37b_row2_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_bb37b_row3_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_bb37b_row3_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_bb37b_row3_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_bb37b_row3_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_bb37b_row4_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_bb37b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >q_OpeningHours</th>
#       <th class="col_heading level0 col1" >q_2017 Total Households</th>
#       <th class="col_heading level0 col2" >q_2017 Purchasing Power: Per Capita</th>
#       <th class="col_heading level0 col3" >q_2017 Medical Products: Per Capita</th>
#       <th class="col_heading level0 col4" >q_5th Quint by Total HH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb37b_level0_row0" class="row_heading level0 row0" >q_OpeningHours</th>
#       <td id="T_bb37b_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_bb37b_row0_col1" class="data row0 col1" >0.11</td>
#       <td id="T_bb37b_row0_col2" class="data row0 col2" >0.05</td>
#       <td id="T_bb37b_row0_col3" class="data row0 col3" >0.03</td>
#       <td id="T_bb37b_row0_col4" class="data row0 col4" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_bb37b_level0_row1" class="row_heading level0 row1" >q_2017 Total Households</th>
#       <td id="T_bb37b_row1_col0" class="data row1 col0" >0.11</td>
#       <td id="T_bb37b_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_bb37b_row1_col2" class="data row1 col2" >0.38</td>
#       <td id="T_bb37b_row1_col3" class="data row1 col3" >0.01</td>
#       <td id="T_bb37b_row1_col4" class="data row1 col4" >-0.28</td>
#     </tr>
#     <tr>
#       <th id="T_bb37b_level0_row2" class="row_heading level0 row2" >q_2017 Purchasing Power: Per Capita</th>
#       <td id="T_bb37b_row2_col0" class="data row2 col0" >0.05</td>
#       <td id="T_bb37b_row2_col1" class="data row2 col1" >0.38</td>
#       <td id="T_bb37b_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_bb37b_row2_col3" class="data row2 col3" >0.49</td>
#       <td id="T_bb37b_row2_col4" class="data row2 col4" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_bb37b_level0_row3" class="row_heading level0 row3" >q_2017 Medical Products: Per Capita</th>
#       <td id="T_bb37b_row3_col0" class="data row3 col0" >0.03</td>
#       <td id="T_bb37b_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_bb37b_row3_col2" class="data row3 col2" >0.49</td>
#       <td id="T_bb37b_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_bb37b_row3_col4" class="data row3 col4" >-0.18</td>
#     </tr>
#     <tr>
#       <th id="T_bb37b_level0_row4" class="row_heading level0 row4" >q_5th Quint by Total HH</th>
#       <td id="T_bb37b_row4_col0" class="data row4 col0" >-0.03</td>
#       <td id="T_bb37b_row4_col1" class="data row4 col1" >-0.28</td>
#       <td id="T_bb37b_row4_col2" class="data row4 col2" >0.43</td>
#       <td id="T_bb37b_row4_col3" class="data row4 col3" >-0.18</td>
#       <td id="T_bb37b_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>
